# %%
library(twitteR)
consumer_key <- "Z0egQEJ8AQppntpTQ1MajGiGu"
consumer_secret <- "RuYWOnZGn5D4Fat0uKeZGcYZ2Bxg4srqh5n1PGwldALHR2dPBt"
access_token <- "827756178105102336-YlTID0aD4LLpEqOh1N0LGLgT2B5uh63"
access_secret <- "vNQn92OzvGtuNFfV1lFLOPLwn3chA1r1BopdPP83tl8QW"
twitteR::setup_twitter_oauth(consumer_key, consumer_secret, access_token, access_secret)
tw = twitteR::searchTwitter('#psychopath', n = 1e4, since = '2018-03-19', retryOnRateLimit = 1e3, lang="en")
#options("encoding" = "UTF-8")
d = twitteR::twListToDF(tw)
d[1]
write.table(d[1],"tweets1.txt",)
# Out:
# [1] "Using direct authentication"
# Warning message in doRppAPICall("search/tweets", n, params = params, retryOnRateLimit = retryOnRateLimit, :
# "10000 tweets were requested but the API can only return 795"
#     text
# 1   RT @juliatetley: @miss_vertonghen @cbrmj68 @LeeWolfX @lee_ludlow_art @awkward_1110 @Stephan93120277 @Sleepynaps @_Pehicc @Tiki4077 @Forever
# 2   RT @ToneyeEyenot: Descend into the foulest depths of Hell #horror #death #insanity #terror #Amazon #books #indieauthors #darkness #psychopa
# 3   RT @julianpentest: New #psychoPATH beta available:\n- new UI\n- more options\n- Scanner integration https://t.co/cs9bMDU5Xw
# 4   Study Shows Psychopaths Would Sacrifice One Life to Save More Lives https://t.co/i1z9xv291x #psychopath #mentalhealth
# 5   Study Shows Psychopaths Would Sacrifice One Life to Save More Lives https://t.co/Z5vz0OeA3r #psychopath #mentalhealth
# ...
